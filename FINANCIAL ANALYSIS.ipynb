# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv(r"C:\Users\prasa\OneDrive\Documents\KC\CODES 2024\INTERNSHIP_UM_KH\UM\Financial Analytics data.csv")

# %%
data
# Out:
#      S.No.             Name  Mar Cap - Crore  Sales Qtr - Crore  Unnamed: 4
# 0        1   Reliance Inds.        583436.72           99810.00         NaN
# 1        2              TCS        563709.84           30904.00         NaN
# 2        3        HDFC Bank        482953.59           20581.27         NaN
# 3        4              ITC        320985.27            9772.02         NaN
# 4        5          H D F C        289497.37           16840.51         NaN
# ..     ...              ...              ...                ...         ...
# 483    496  Lak. Vilas Bank          3029.57             790.17         NaN
# 484    497            NOCIL          3026.26             249.27         NaN
# 485    498    Orient Cement          3024.32             511.53         NaN
# 486    499  Natl.Fertilizer          3017.07            2840.75         NaN
# 487    500        L T Foods              NaN                NaN         NaN
#
# [488 rows x 5 columns]

# %%
# Display the first few rows of the dataset
print(data.head())

# Check for missing values
print(data.isnull().sum())
# Out:
#    S.No.            Name  Mar Cap - Crore  Sales Qtr - Crore  Unnamed: 4
# 0      1  Reliance Inds.        583436.72           99810.00         NaN
# 1      2             TCS        563709.84           30904.00         NaN
# 2      3       HDFC Bank        482953.59           20581.27         NaN
# 3      4             ITC        320985.27            9772.02         NaN
# 4      5         H D F C        289497.37           16840.51         NaN
# S.No.                  0
# Name                   0
# Mar Cap - Crore        9
# Sales Qtr - Crore    123
# Unnamed: 4           394
# dtype: int64

# %%
import matplotlib.pyplot as plt

# Histogram for Market Capitalization
plt.hist(data['Mar Cap - Crore'], bins=20)
plt.xlabel('Market Capitalization (Crore)')
plt.ylabel('Frequency')
plt.title('Distribution of Market Capitalization')
plt.show()

# %%
# Histogram for Quarterly Sales
plt.hist(data['Sales Qtr - Crore'], bins=20)
plt.xlabel('Quarterly Sales (Crore)')
plt.ylabel('Frequency')
plt.title('Distribution of Quarterly Sales')
plt.show()

# %%
# Calculate growth rate
data['Growth Rate'] = (data['Sales Qtr - Crore'] - data['Sales Qtr - Crore'].shift(1)) / data['Sales Qtr - Crore'].shift(1) * 100

# Calculate profitability ratio (example)
data['Profitability Ratio'] = data['Mar Cap - Crore'] / data['Sales Qtr - Crore']

# %%
# Correlation analysis
correlation_matrix = data.corr()
print(correlation_matrix)
# Out:
#                         S.No.  Mar Cap - Crore  Sales Qtr - Crore  Unnamed: 4  \
# S.No.                1.000000        -0.545454          -0.421218   -0.670564
# Mar Cap - Crore     -0.545454         1.000000           0.620702    0.734338
# Sales Qtr - Crore   -0.421218         0.620702           1.000000         NaN
# Unnamed: 4          -0.670564         0.734338                NaN    1.000000
# Growth Rate          0.021575        -0.069044           0.253502         NaN
# Profitability Ratio -0.163282         0.097460          -0.190282         NaN
#
#                      Growth Rate  Profitability Ratio
# S.No.                   0.021575            -0.163282
# Mar Cap - Crore        -0.069044             0.097460
# Sales Qtr - Crore       0.253502            -0.190282
# Unnamed: 4                   NaN                  NaN
# Growth Rate             1.000000            -0.374337
# Profitability Ratio    -0.374337             1.000000

# %%
# Scatter plot for Market Capitalization vs. Quarterly Sales
plt.scatter(data['Mar Cap - Crore'], data['Sales Qtr - Crore'])
plt.xlabel('Market Capitalization (Crore)')
plt.ylabel('Quarterly Sales (Crore)')
plt.title('Market Capitalization vs. Quarterly Sales')
plt.show()

# %%
data.to_csv("modified_dataset.csv", index=False)
